# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax = fig.gca()
ax.margins(0.08)
ax.axis("off")
fig.tight_layout()

G = nx.Graph()

G.add_edge("d", "b", weight=11)
G.add_edge("d", "c", weight=2)
G.add_edge("b", "a", weight=4)
G.add_edge("b", "f", weight=6)
G.add_edge("c", "e", weight=2)
G.add_edge("c", "f", weight=6)
G.add_edge("d", "a", weight=8)
G.add_edge("e", "f", weight=4)


elarge = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] > 0.5]
# esmall = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] <= 0.5]

pos = nx.spring_layout(G, seed=7)  # positions for all nodes - seed for reproducibility

colours = ['cornflowerblue']*len(G.nodes)

# nodes
nx.draw_networkx_nodes(G, pos, node_size=700, ax=ax, node_color=colours)

# edges
nx.draw_networkx_edges(G, pos, edgelist=elarge, width=6, ax=ax)

# node labels
nx.draw_networkx_labels(G, pos, font_size=20, font_family="sans-serif", ax=ax)
# edge weight labels
edge_labels = nx.get_edge_attributes(G, "weight")
nx.draw_networkx_edge_labels(G, pos, edge_labels, ax=ax)



fig.savefig('weighted_graph_0.png')

# %%
fig, ax = plt.subplots()
ax = fig.gca()
ax.margins(0.08)
ax.axis("off")
fig.tight_layout()

colours1 = colours.copy()
colours1[3] = 'orange'
colours1[-1] = 'red'
colours1[2] = 'red'

# nodes
nx.draw_networkx_nodes(G, pos, node_size=700, ax=ax, node_color=colours1)

# edges
nx.draw_networkx_edges(G, pos, edgelist=elarge, width=6, ax=ax)

# node labels
nx.draw_networkx_labels(G, pos, font_size=20, font_family="sans-serif", ax=ax)
# edge weight labels
edge_labels = nx.get_edge_attributes(G, "weight")
nx.draw_networkx_edge_labels(G, pos, edge_labels, ax=ax)

fig.savefig('weighted_graph_1.png')

# %%
fig, ax = plt.subplots()
ax = fig.gca()
ax.margins(0.08)
ax.axis("off")
fig.tight_layout()

colours2 = colours1.copy()
colours2[1] = 'orange'

edge_colours2 = ['black']*len(G.edges)
edge_colours2[3] = 'orange'

# nodes
nx.draw_networkx_nodes(G, pos, node_size=700, ax=ax, node_color=colours2)

# edges
nx.draw_networkx_edges(G, pos, edgelist=elarge, width=6, ax=ax, edge_color=edge_colours2)

# node labels
nx.draw_networkx_labels(G, pos, font_size=20, font_family="sans-serif", ax=ax)
# edge weight labels
edge_labels = nx.get_edge_attributes(G, "weight")
nx.draw_networkx_edge_labels(G, pos, edge_labels, ax=ax)

fig.savefig('weighted_graph_2.png')

# %%
fig, ax = plt.subplots()
ax = fig.gca()
ax.margins(0.08)
ax.axis("off")
fig.tight_layout()

colours3 = colours1.copy()
colours3[0] = 'orange'
colours3[1] = 'gray'

edge_colours3 = ['black']*len(G.edges)
edge_colours3[2] = 'orange'

# nodes
nx.draw_networkx_nodes(G, pos, node_size=700, ax=ax, node_color=colours3)

# edges
nx.draw_networkx_edges(G, pos, edgelist=elarge, width=6, ax=ax, edge_color=edge_colours3)

# node labels
nx.draw_networkx_labels(G, pos, font_size=20, font_family="sans-serif", ax=ax)
# edge weight labels
edge_labels = nx.get_edge_attributes(G, "weight")
nx.draw_networkx_edge_labels(G, pos, edge_labels, ax=ax)

fig.savefig('weighted_graph_3.png')

# %%
fig, ax = plt.subplots()
ax = fig.gca()
ax.margins(0.08)
ax.axis("off")
fig.tight_layout()

colours4 = colours1.copy()
colours4[0] = 'orange'
colours4[1] = 'gray'

edge_colours4 = ['black']*len(G.edges)
edge_colours4[1] = 'orange'
edge_colours4[2] = 'orange'

# nodes
nx.draw_networkx_nodes(G, pos, node_size=700, ax=ax, node_color=colours4)

# edges
nx.draw_networkx_edges(G, pos, edgelist=elarge, width=6, ax=ax, edge_color=edge_colours4)

# node labels
nx.draw_networkx_labels(G, pos, font_size=20, font_family="sans-serif", ax=ax)
# edge weight labels
edge_labels = nx.get_edge_attributes(G, "weight")
nx.draw_networkx_edge_labels(G, pos, edge_labels, ax=ax)

fig.savefig('weighted_graph_4.png')

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax = fig.gca()
ax.margins(0.2)
ax.axis("off")
# fig.tight_layout()

G = nx.Graph()

G.add_edge("state_d", "state_b", weight=11)
G.add_edge("state_d", "goal_state_2", weight=2)
G.add_edge("state_b", "initial_state", weight=4)
G.add_edge("state_b", "state_f", weight=6)
G.add_edge("goal_state_2", "goal_state_1", weight=2)
G.add_edge("goal_state_2", "state_f", weight=6)
G.add_edge("state_d", "initial_state", weight=8)
G.add_edge("goal_state_1", "state_f", weight=4)


elarge = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] > 0.5]
# esmall = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] <= 0.5]

pos = nx.spring_layout(G, seed=7)  # positions for all nodes - seed for reproducibility

colours = ['cornflowerblue']*len(G.nodes)

# nodes
nx.draw_networkx_nodes(G, pos, node_size=700, ax=ax, node_color=colours)

# edges
nx.draw_networkx_edges(G, pos, edgelist=elarge, width=6, ax=ax)

# node labels
nx.draw_networkx_labels(G, pos, font_size=20, font_family="sans-serif", ax=ax)
# edge weight labels
edge_labels = nx.get_edge_attributes(G, "weight")
nx.draw_networkx_edge_labels(G, pos, edge_labels, ax=ax)

# fig.tight_layout()


fig.savefig('weighted_graph_0.png')
